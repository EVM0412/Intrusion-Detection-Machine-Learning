# %% [markdown]
# # **Data Preprocessing**

# %%
# importing required libraries
import numpy as np
import pandas as pd

import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt

# importing library for support vector machine classifier
from sklearn.svm import SVC
# importing library for K-neares-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
# importing library for Linear Discriminant Analysis Model
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# importing library for Quadratic Discriminant Analysis Model
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn import metrics
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import classification_report # for generating a classification report of model

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from keras.layers import Dense # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.models import model_from_json # saving and loading trained model

from keras.layers import LSTM
from keras.layers import Input
from keras.models import Model

# representation of model layers
from keras.util import plot_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[114], line 45
#      42 from keras.models import Model
#      44 # representation of model layers
# ---> 45 from keras.util import plot_model
#
# ModuleNotFoundError: No module named 'keras.util'

# %%
# dataset doesn't have column names, so we have to provide it
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty_level"]

# %%
# importing dataset
data = pd.read_csv('/content/drive/MyDrive/NSL-KDD/KDDTrain+.txt',header=None, names=col_names)
#data = pd.read_csv('datasets/KDDTrain+.txt',header=None, names=col_names)

# %%
# print dataset
data

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty_level'],axis=1,inplace=True)
data.shape

# %%
# descriptive statistics of dataset
data.describe()

# %%
# number of attack labels 
data['label'].value_counts()

# %%
# changing attack labels to their respective attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail',
       'snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
# calling change_label() function
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()

# %% [markdown]
# # **Data Normalization**

# %%
# selecting numeric attributes columns from data
numeric_col = data.select_dtypes(include='number').columns

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
# data before normalization
data.head()

# %%
# calling the normalization() function
data = normalization(data.copy(),numeric_col)

# %%
# data after normalization
data.head()

# %% [markdown]
# # **One-hot-encoding**

# %%
# selecting categorical data attributes
cat_col = ['protocol_type','service','flag']

# %%
# creating a dataframe with only categorical attributes
categorical = data[cat_col]
categorical.head()

# %%
# one-hot-encoding categorical attributes using pandas.get_dummies() function
categorical = pd.get_dummies(categorical,columns=cat_col)
categorical.head()

# %% [markdown]
# # **Binary Classification**

# %%
# changing attack labels into two categories 'normal' and 'abnormal'
bin_label = pd.DataFrame(data.label.map(lambda x:'normal' if x=='normal' else 'abnormal'))

# %%
# creating a dataframe with binary labels (normal,abnormal)
bin_data = data.copy()
bin_data['label'] = bin_label

# %%
# label encoding (0,1) binary labels (abnormal,normal)
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['intrusion'] = enc_label

# %%
np.save("labels/le1_classes.npy",le1.classes_,allow_pickle=True)

# %%
# dataset with binary labels and label encoded column
bin_data.head()

# %%
# one-hot-encoding attack label
bin_data = pd.get_dummies(bin_data,columns=['label'],prefix="",prefix_sep="") 
bin_data['label'] = bin_label
bin_data

# %%
# pie chart distribution of normal and abnormal labels
plt.figure(figsize=(8,8))
plt.pie(bin_data.label.value_counts(),labels=bin_data.label.unique(),autopct='%0.2f%%')
plt.title("Pie chart distribution of normal and abnormal labels")
plt.legend()
plt.savefig('plots/Pie_chart_binary.png')
plt.show()

# %% [markdown]
# # **Multi-class Classification**

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
multi_data = data.copy()
multi_label = pd.DataFrame(multi_data.label)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le2.fit_transform)
multi_data['intrusion'] = enc_label

# %%
np.save("labels/le2_classes.npy",le2.classes_,allow_pickle=True)

# %%
# one-hot-encoding attack label
multi_data = pd.get_dummies(multi_data,columns=['label'],prefix="",prefix_sep="") 
multi_data['label'] = multi_label
multi_data

# %%
# pie chart distribution of multi-class labels
plt.figure(figsize=(8,8))
plt.pie(multi_data.label.value_counts(),labels=multi_data.label.unique(),autopct='%0.2f%%')
plt.title('Pie chart distribution of multi-class labels')
plt.legend()
plt.savefig('plots/Pie_chart_multi.png')
plt.show()

# %% [markdown]
# # **Feature Extraction**

# %%
# creating a dataframe with only numeric attributes of binary class dataset and encoded label attribute 
numeric_bin = bin_data[numeric_col]
numeric_bin['intrusion'] = bin_data['intrusion']

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute 
corr= numeric_bin.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_bin = bin_data[['count','srv_serror_rate','serror_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
                         'logged_in','dst_host_same_srv_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_bin = numeric_bin.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
bin_data = numeric_bin.join(bin_data[['intrusion','abnormal','normal','label']])

# %%
# saving final dataset to disk
bin_data.to_csv("./datasets/bin_data.csv")
# final dataset for binary classification
bin_data

# %%
# creating a dataframe with only numeric attributes of multi-class dataset and encoded label attribute 
numeric_multi = multi_data[numeric_col]
numeric_multi['intrusion'] = multi_data['intrusion']

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute 
corr = numeric_multi.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_multi = multi_data[['count','logged_in','srv_serror_rate','serror_rate','dst_host_serror_rate',
                        'dst_host_same_srv_rate','dst_host_srv_serror_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_multi = numeric_multi.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
multi_data = numeric_multi.join(multi_data[['intrusion','Dos','Probe','R2L','U2R','normal','label']])

# %%
# saving final dataset to disk
multi_data.to_csv('./datasets/multi_data.csv')

# final dataset for multi-class classification
multi_data
# Out:
#            count  logged_in  srv_serror_rate  serror_rate  \
# 0      -0.717045  -0.809262        -0.631929    -0.637209
# 1      -0.620982  -0.809262        -0.631929    -0.637209
# 2       0.339648  -0.809262         1.605104     1.602664
# 3      -0.690846   1.235694        -0.184522    -0.189235
# 4      -0.472521   1.235694        -0.631929    -0.637209
# ...          ...        ...              ...          ...
# 125968  0.872361  -0.809262         1.605104     1.602664
# 125969 -0.717045  -0.809262        -0.631929    -0.637209
# 125970 -0.725778   1.235694        -0.631929    -0.637209
# 125971  0.523041  -0.809262         1.605104     1.602664
# 125972 -0.725778   1.235694        -0.631929    -0.637209
#
#         dst_host_serror_rate  dst_host_same_srv_rate  \
# 0                  -0.639532               -0.782367
# 1                  -0.639532               -1.161030
# 2                   1.608759               -0.938287
# 3                  -0.572083                1.066401
# 4                  -0.639532                1.066401
# ...                      ...                     ...
# 125968              1.608759               -0.938287
# 125969             -0.639532                0.977304
# 125970              0.979238               -0.893738
# 125971              1.608759               -1.094207
# 125972             -0.639532               -0.492801
#
#         dst_host_srv_serror_rate  dst_host_srv_count  same_srv_rate  \
# 0                      -0.624871           -0.818890       0.771283
# 1                      -0.624871           -1.035688      -1.321428
# 2                       1.618955           -0.809857      -1.389669
# 3                      -0.602433            1.258754       0.771283
# 4                      -0.624871            1.258754       0.771283
# ...                          ...                 ...            ...
# 125968                  1.618955           -0.818890      -1.184947
# 125969                 -0.624871            1.159389       0.771283
# 125970                 -0.624871           -0.773724       0.771283
# 125971                  1.618955           -0.972455      -1.366922
# 125972                 -0.624871           -0.349162       0.771283
#
#         protocol_type_icmp  ...  flag_S3  flag_SF  flag_SH  intrusion  Dos  \
# 0                        0  ...        0        1        0          4    0
# 1                        0  ...        0        1        0          4    0
# 2                        0  ...        0        0        0          0    1
# 3                        0  ...        0        1        0          4    0
# 4                        0  ...        0        1        0          4    0
# ...                    ...  ...      ...      ...      ...        ...  ...
# 125968                   0  ...        0        0        0          0    1
# 125969                   0  ...        0        1        0          4    0
# 125970                   0  ...        0        1        0          4    0
# 125971                   0  ...        0        0        0          0    1
# 125972                   0  ...        0        1        0          4    0
#
#         Probe  R2L  U2R  normal   label
# 0           0    0    0       1  normal
# 1           0    0    0       1  normal
# 2           0    0    0       0     Dos
# 3           0    0    0       1  normal
# 4           0    0    0       1  normal
# ...       ...  ...  ...     ...     ...
# 125968      0    0    0       0     Dos
# 125969      0    0    0       1  normal
# 125970      0    0    0       1  normal
# 125971      0    0    0       0     Dos
# 125972      0    0    0       1  normal
#
# [125973 rows x 100 columns]

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
# using kernel as linear 
lsvm = SVC(kernel='linear',gamma='auto') 
lsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
pkl_filename = "./models/lsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred = lsvm.predict(X_test) # predicting target attribute on testing dataset
ac = accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("LSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# LSVM-Classifier Binary Set-Accuracy is  96.69778370483266

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.96      0.96     14720
#       normal       0.96      0.97      0.97     16774
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.03302216295167333
# Mean Squared Error -  0.03302216295167333
# Root Mean Squared Error -  0.1817200125238641
# R2 Score -  86.74560396265441
# Accuracy -  96.69778370483266

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:500], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:500].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Linear SVM Binary Classification")
plt.savefig('plots/lsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Binary Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto') # using kernal as polynomial for quadratic svm
qsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='poly')

# %%
pkl_filename = "./models/qsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk 
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred=qsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("QSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# QSVM-Classifier Binary Set-Accuracy is  95.71029402425859

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.92      0.95     14720
#       normal       0.93      0.99      0.96     16774
#
#     accuracy                           0.96     31494
#    macro avg       0.96      0.95      0.96     31494
# weighted avg       0.96      0.96      0.96     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.04289705975741411
# Mean Squared Error -  0.04289705975741411
# Root Mean Squared Error -  0.20711605383797296
# R2 Score -  83.24290009836652
# Accuracy -  95.71029402425859

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Quadratic SVM Binary Classification")
plt.savefig('plots/qsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Binary Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5) # creating model for 5 neighbors
knn.fit(X_train,y_train) # training model on training dataset
# Out:
# KNeighborsClassifier()

# %%
pkl_filename = "./models/knn_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred=knn.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("KNN-Classifier Binary Set-Accuracy is ", ac)
# Out:
# KNN-Classifier Binary Set-Accuracy is  98.5552803708643

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.98      0.98     14720
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.99     31494
#    macro avg       0.99      0.99      0.99     31494
# weighted avg       0.99      0.99      0.99     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.014447196291357083
# Mean Squared Error -  0.014447196291357083
# Root Mean Squared Error -  0.12019649034542183
# R2 Score -  94.19677669828046
# Accuracy -  98.5552803708643

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("KNN Binary Classification")
plt.savefig('plots/knn_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Linear Discriminant Analysis Classifier (Binary Classification)**

# %%
lda = LinearDiscriminantAnalysis() 
lda.fit(X_train, y_train)  # training model on training dataset
# Out:
# LinearDiscriminantAnalysis()

# %%
pkl_filename = "./models/lda_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lda = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred = lda.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("LDA-Classifier Set-Accuracy is ", ac)
# Out:
# LDA-Classifier Set-Accuracy is  96.70730932876104

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.96      0.96     14720
#       normal       0.96      0.98      0.97     16774
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.03292690671238966
# Mean Squared Error -  0.03292690671238966
# Root Mean Squared Error -  0.1814577270671868
# R2 Score -  86.8001441639753
# Accuracy -  96.70730932876104

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Linear Discriminant Analysis Binary Classification")
plt.savefig('plots/lda_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Quadratic Discriminant Analysis Classifier (Binary Classification)**

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train) # training model on training dataset
# Out:
# C:\Users\Aswin\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis()

# %%
pkl_filename = "./models/qda_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qda = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred = qda.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QDA-Classifier Set-Accuracy is ", ac)
# Out:
# QDA-Classifier Set-Accuracy is  68.5241633326983

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       1.00      0.33      0.49     14720
#       normal       0.63      1.00      0.77     16774
#
#     accuracy                           0.69     31494
#    macro avg       0.81      0.66      0.63     31494
# weighted avg       0.80      0.69      0.64     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.3147583666730171
# Mean Squared Error -  0.3147583666730171
# Root Mean Squared Error -  0.5610333026416677
# R2 Score -  13.212850681826438
# Accuracy -  68.5241633326983

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Quadratic Discriminant Analysis Binary Classification")
plt.savefig('plots/qda_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].values # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']].values # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # creating model

# adding input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with sigmoid activation
mlp.add(Dense(units=1,activation='sigmoid'))
# Out:
# C:\Users\Aswin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 50)                  │           4,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,751 (18.56 KB)
#  Trainable params: 4,751 (18.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# training the model on training dataset
history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7727 - loss: 0.5735 - val_accuracy: 0.8734 - val_loss: 0.4179
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8778 - loss: 0.3849 - val_accuracy: 0.8963 - val_loss: 0.3002
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.2816 - val_accuracy: 0.9212 - val_loss: 0.2356
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.2234 - val_accuracy: 0.9461 - val_loss: 0.1985
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9479 - loss: 0.1898 - val_accuracy: 0.9541 - val_loss: 0.1749
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9563 - loss: 0.1682 - val_accuracy: 0.9599 - val_loss: 0.1590
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.1541 - val_accuracy: 0.9628 - val_loss: 0.1475
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9633 - loss: 0.1449 - val_accuracy: 0.9640 - val_loss: 0.1388
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9647 - loss: 0.1361 - val_accuracy: 0.9644 - val_loss: 0.1319
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9655 - loss: 0.1280 - val_accuracy: 0.9653 - val_loss: 0.1261
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9666 - loss: 0.1221 - val_accuracy: 0.9672 - val_loss: 0.1211
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9689 - loss: 0.1156 - val_accuracy: 0.9688 - val_loss: 0.1169
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9695 - loss: 0.1135 - val_accuracy: 0.9694 - val_loss: 0.1131
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9704 - loss: 0.1093 - val_accuracy: 0.9698 - val_loss: 0.1098
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9709 - loss: 0.1055 - val_accuracy: 0.9702 - val_loss: 0.1069
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9698 - loss: 0.1057 - val_accuracy: 0.9702 - val_loss: 0.1042
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9709 - loss: 0.1009 - val_accuracy: 0.9704 - val_loss: 0.1018
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9703 - loss: 0.0998 - val_accuracy: 0.9703 - val_loss: 0.0996
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9721 - loss: 0.0952 - val_accuracy: 0.9705 - val_loss: 0.0977
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9715 - loss: 0.0936 - val_accuracy: 0.9706 - val_loss: 0.0959
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9715 - loss: 0.0921 - val_accuracy: 0.9707 - val_loss: 0.0943
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.0899 - val_accuracy: 0.9708 - val_loss: 0.0927
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9718 - loss: 0.0886 - val_accuracy: 0.9708 - val_loss: 0.0913
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9715 - loss: 0.0894 - val_accuracy: 0.9707 - val_loss: 0.0900
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9718 - loss: 0.0866 - val_accuracy: 0.9707 - val_loss: 0.0888
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.0881 - val_accuracy: 0.9704 - val_loss: 0.0877
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0851 - val_accuracy: 0.9703 - val_loss: 0.0866
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9710 - loss: 0.0847 - val_accuracy: 0.9703 - val_loss: 0.0856
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.0823 - val_accuracy: 0.9703 - val_loss: 0.0847
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9726 - loss: 0.0813 - val_accuracy: 0.9703 - val_loss: 0.0838
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9717 - loss: 0.0810 - val_accuracy: 0.9706 - val_loss: 0.0830
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9718 - loss: 0.0816 - val_accuracy: 0.9706 - val_loss: 0.0822
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9721 - loss: 0.0796 - val_accuracy: 0.9706 - val_loss: 0.0815
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9722 - loss: 0.0794 - val_accuracy: 0.9707 - val_loss: 0.0808
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9725 - loss: 0.0772 - val_accuracy: 0.9708 - val_loss: 0.0802
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9726 - loss: 0.0778 - val_accuracy: 0.9709 - val_loss: 0.0796
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9725 - loss: 0.0771 - val_accuracy: 0.9712 - val_loss: 0.0790
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9722 - loss: 0.0763 - val_accuracy: 0.9712 - val_loss: 0.0784
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9720 - loss: 0.0781 - val_accuracy: 0.9712 - val_loss: 0.0779
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9726 - loss: 0.0760 - val_accuracy: 0.9713 - val_loss: 0.0774
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.0753 - val_accuracy: 0.9713 - val_loss: 0.0770
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9728 - loss: 0.0757 - val_accuracy: 0.9713 - val_loss: 0.0765
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9735 - loss: 0.0728 - val_accuracy: 0.9714 - val_loss: 0.0761
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9738 - loss: 0.0728 - val_accuracy: 0.9714 - val_loss: 0.0757
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.0746 - val_accuracy: 0.9728 - val_loss: 0.0752
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9745 - loss: 0.0719 - val_accuracy: 0.9732 - val_loss: 0.0748
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0728 - val_accuracy: 0.9738 - val_loss: 0.0744
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 0.0718 - val_accuracy: 0.9739 - val_loss: 0.0741
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9752 - loss: 0.0720 - val_accuracy: 0.9742 - val_loss: 0.0738
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.0731 - val_accuracy: 0.9746 - val_loss: 0.0734
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9759 - loss: 0.0718 - val_accuracy: 0.9747 - val_loss: 0.0731
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.0697 - val_accuracy: 0.9747 - val_loss: 0.0728
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9763 - loss: 0.0702 - val_accuracy: 0.9751 - val_loss: 0.0725
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.0694 - val_accuracy: 0.9751 - val_loss: 0.0722
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.0682 - val_accuracy: 0.9753 - val_loss: 0.0720
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0705 - val_accuracy: 0.9752 - val_loss: 0.0717
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.0698 - val_accuracy: 0.9752 - val_loss: 0.0714
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9774 - loss: 0.0685 - val_accuracy: 0.9754 - val_loss: 0.0712
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9763 - loss: 0.0706 - val_accuracy: 0.9755 - val_loss: 0.0710
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0685 - val_accuracy: 0.9755 - val_loss: 0.0708
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0683 - val_accuracy: 0.9758 - val_loss: 0.0705
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9774 - loss: 0.0680 - val_accuracy: 0.9757 - val_loss: 0.0703
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0674 - val_accuracy: 0.9756 - val_loss: 0.0702
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.0672 - val_accuracy: 0.9759 - val_loss: 0.0699
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9771 - loss: 0.0680 - val_accuracy: 0.9760 - val_loss: 0.0698
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9788 - loss: 0.0657 - val_accuracy: 0.9758 - val_loss: 0.0695
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0670 - val_accuracy: 0.9760 - val_loss: 0.0693
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9767 - loss: 0.0691 - val_accuracy: 0.9759 - val_loss: 0.0692
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0651 - val_accuracy: 0.9759 - val_loss: 0.0690
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9777 - loss: 0.0660 - val_accuracy: 0.9757 - val_loss: 0.0688
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9774 - loss: 0.0663 - val_accuracy: 0.9759 - val_loss: 0.0687
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0665 - val_accuracy: 0.9759 - val_loss: 0.0685
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9782 - loss: 0.0655 - val_accuracy: 0.9758 - val_loss: 0.0683
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0651 - val_accuracy: 0.9758 - val_loss: 0.0681
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0659 - val_accuracy: 0.9760 - val_loss: 0.0680
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0662 - val_accuracy: 0.9765 - val_loss: 0.0678
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9786 - loss: 0.0642 - val_accuracy: 0.9767 - val_loss: 0.0677
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0645 - val_accuracy: 0.9761 - val_loss: 0.0675
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9777 - loss: 0.0659 - val_accuracy: 0.9767 - val_loss: 0.0674
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.0632 - val_accuracy: 0.9766 - val_loss: 0.0672
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0647 - val_accuracy: 0.9765 - val_loss: 0.0672
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9787 - loss: 0.0642 - val_accuracy: 0.9767 - val_loss: 0.0670
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9782 - loss: 0.0660 - val_accuracy: 0.9767 - val_loss: 0.0668
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.0646 - val_accuracy: 0.9766 - val_loss: 0.0667
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9788 - loss: 0.0634 - val_accuracy: 0.9767 - val_loss: 0.0665
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0636 - val_accuracy: 0.9766 - val_loss: 0.0664
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9789 - loss: 0.0629 - val_accuracy: 0.9765 - val_loss: 0.0663
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9777 - loss: 0.0644 - val_accuracy: 0.9766 - val_loss: 0.0663
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0655 - val_accuracy: 0.9768 - val_loss: 0.0661
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9785 - loss: 0.0639 - val_accuracy: 0.9767 - val_loss: 0.0660
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0631 - val_accuracy: 0.9767 - val_loss: 0.0660
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9782 - loss: 0.0640 - val_accuracy: 0.9768 - val_loss: 0.0658
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9786 - loss: 0.0634 - val_accuracy: 0.9767 - val_loss: 0.0658
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.0626 - val_accuracy: 0.9766 - val_loss: 0.0657
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0640 - val_accuracy: 0.9768 - val_loss: 0.0656
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9787 - loss: 0.0629 - val_accuracy: 0.9769 - val_loss: 0.0655
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9785 - loss: 0.0631 - val_accuracy: 0.9769 - val_loss: 0.0654
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.0625 - val_accuracy: 0.9767 - val_loss: 0.0653
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0628 - val_accuracy: 0.9769 - val_loss: 0.0653
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.0622 - val_accuracy: 0.9768 - val_loss: 0.0651

# %%
filepath = './models/mlp_binary.json'
weightspath = './weights/mlp_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}')
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 1s 637us/step - accuracy: 0.9770 - loss: 0.0667
# Test results - Loss: 0.06354537606239319 - Accuracy: 97.8186309337616

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Plot of loss vs epoch for train and test dataset')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_loss.png')
plt.show()

# %%
plot_model(mlp, to_file='plots/mlp_binary.png', show_shapes=True,)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
y_pred = mlp.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/mlp_binary_roc.png')
plt.show()

# %%
pred = mlp.predict(X_test)
y_classes = (mlp.predict(X_test)>0.5).astype('int32')
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.9869440801240015
# F1 Score -  0.97967275201941
# Precision Score -  0.9725077835869118

# %% [markdown]
# # **Long Short-Term Memory Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93] # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values

# %%
y_train = np.array(y_train)

# %%
x_train = np.reshape(X_train, (X_train.shape[0],1,X_train.shape[1]))

# %%
x_train.shape
# Out:
# (94479, 1, 93)

# %%
lst = Sequential()
# input layer and LSTM layer with 50 neurons
lst.add(LSTM(50,input_dim=93))

# outpute layer with sigmoid activation
lst.add(Dense(1,activation='sigmoid'))
# Out:
# C:\Users\Aswin\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 3
#       1 lst = Sequential()
#       2 # input layer and LSTM layer with 50 neurons
# ----> 3 lst.add(LSTM(50,input_dim=93))
#       5 # outpute layer with sigmoid activation
#       6 lst.add(Dense(1,activation='sigmoid'))
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:116, in Sequential.add(self, layer, rebuild)
#     114 self._layers.append(layer)
#     115 if rebuild:
# --> 116     self._maybe_rebuild()
#     117 else:
#     118     self.built = False
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:135, in Sequential._maybe_rebuild(self)
#     133 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     134     input_shape = self._layers[0].batch_shape
# --> 135     self.build(input_shape)
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\layer.py:223, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     220 @wraps(original_build_method)
#     221 def build_wrapper(*args, **kwargs):
#     222     with backend.name_scope(obj.name, caller=obj):
# --> 223         original_build_method(*args, **kwargs)
#     224     # Record build config.
#     225     signature = inspect.signature(original_build_method)
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:176, in Sequential.build(self, input_shape)
#     174 for layer in self._layers[1:]:
#     175     try:
# --> 176         x = layer(x)
#     177     except NotImplementedError:
#     178         # Can happen if shape inference is not implemented.
#     179         # TODO: consider reverting inbound nodes on layers processed.
#     180         return
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185     if ndim != spec.ndim:
# --> 186         raise ValueError(
#     187             f'Input {input_index} of layer "{layer_name}" '
#     188             "is incompatible with the layer: "
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     190             f"Full shape received: {shape}"
#     191         )
#     192 if spec.max_ndim is not None:
#     193     if ndim is not None and ndim > spec.max_ndim:
#
# ValueError: Input 0 of layer "lstm_2" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 93)

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# summary of model layers
lst.summary()

# %%
# training the model on training dataset
history = lst.fit(x_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 2
#       1 # training the model on training dataset
# ----> 2 history = lst.fit(x_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py:887, in Trainer._assert_compile_called(self, method_name)
#     885 else:
#     886     msg += f"calling `{method_name}()`."
# --> 887 raise ValueError(msg)
#
# ValueError: You must call `compile()` before using the model.

# %%
X_test = X_test.to_numpy()

# %%
x_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
filepath = './models/lst_binary.json'
weightspath = './weights/lst_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  lst_json = lst.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(lst_json)

  # serialize weights to HDF5
  lst.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  lst = model_from_json(loaded_model_json)

  # load weights into new model
  lst.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# load json and create model
json_file = open(filepath, 'r')
loaded_model_json = json_file.read()
json_file.close()
lst = model_from_json(loaded_model_json)

# load weights into new model
lst.load_weights(weightspath)
print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = lst.evaluate(x_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(lst, to_file='plots/lstm_binary.png', show_shapes=True,)

# %%
y_test.shape

# %%
y_pred = lst.predict(x_test)

# %%
y_pred.shape

# %%
y_pred = lst.predict(x_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/lstm_binary_roc.png')
plt.show()

# %%
y_classes = (lst.predict(x_test)>0.5).astype('int32')

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))

# %% [markdown]
# # **Auto Encoder Classifier (Binary Classification)**

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test = train_test_split(bin_data, test_size=0.25, random_state=42)

# %%
# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_train = X_train.drop(['intrusion','abnormal','normal','label'],axis=1) 

y_test = X_test['intrusion'] # target attribute

# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_test = X_test.drop(['intrusion','abnormal','normal','label'],axis=1)

# %%
X_train = X_train.values
X_test = X_test.values
y_test = y_test.values

# %%
input_dim = X_train.shape[1]
encoding_dim = 50

#input layer
input_layer = Input(shape=(input_dim, ))
#encoding layer with 50 neurons
encoder = Dense(encoding_dim, activation="relu")(input_layer)           
#decoding and output layer
output_layer = Dense(input_dim, activation='softmax')(encoder)

# %%
# creating model with input, encoding, decoding, output layers
autoencoder = Model(inputs=input_layer, outputs=output_layer)

# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# summary of model layers
autoencoder.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 93)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 50)                  │           4,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 93)                  │           4,743 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,443 (36.89 KB)
#  Trainable params: 9,443 (36.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# training the model on training dataset
history = autoencoder.fit(X_train, X_train, epochs=100,batch_size=500,validation_data=(X_test, X_test)).history
# Out:
# Epoch 1/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1164 - loss: 0.1208 - val_accuracy: 0.4317 - val_loss: 0.1062
# Epoch 2/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5296 - loss: 0.1055 - val_accuracy: 0.6974 - val_loss: 0.1051
# Epoch 3/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6960 - loss: 0.1048 - val_accuracy: 0.7046 - val_loss: 0.1049
# Epoch 4/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7221 - loss: 0.1045 - val_accuracy: 0.7797 - val_loss: 0.1048
# Epoch 5/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7812 - loss: 0.1045 - val_accuracy: 0.7999 - val_loss: 0.1047
# Epoch 6/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8154 - loss: 0.1043 - val_accuracy: 0.8042 - val_loss: 0.1047
# Epoch 7/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8276 - loss: 0.1043 - val_accuracy: 0.8580 - val_loss: 0.1047
# Epoch 8/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8484 - loss: 0.1044 - val_accuracy: 0.8704 - val_loss: 0.1047
# Epoch 9/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8612 - loss: 0.1042 - val_accuracy: 0.8772 - val_loss: 0.1047
# Epoch 10/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8601 - loss: 0.1045 - val_accuracy: 0.8687 - val_loss: 0.1046
# Epoch 11/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8601 - loss: 0.1044 - val_accuracy: 0.8673 - val_loss: 0.1046
# Epoch 12/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8625 - loss: 0.1047 - val_accuracy: 0.8581 - val_loss: 0.1046
# Epoch 13/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8631 - loss: 0.1043 - val_accuracy: 0.8620 - val_loss: 0.1046
# Epoch 14/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8704 - loss: 0.1043 - val_accuracy: 0.8776 - val_loss: 0.1046
# Epoch 15/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8721 - loss: 0.1045 - val_accuracy: 0.8808 - val_loss: 0.1046
# Epoch 16/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8752 - loss: 0.1045 - val_accuracy: 0.8718 - val_loss: 0.1046
# Epoch 17/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8780 - loss: 0.1042 - val_accuracy: 0.8806 - val_loss: 0.1046
# Epoch 18/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8820 - loss: 0.1044 - val_accuracy: 0.8912 - val_loss: 0.1046
# Epoch 19/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8850 - loss: 0.1044 - val_accuracy: 0.8803 - val_loss: 0.1046
# Epoch 20/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8824 - loss: 0.1045 - val_accuracy: 0.8959 - val_loss: 0.1046
# Epoch 21/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8878 - loss: 0.1045 - val_accuracy: 0.9170 - val_loss: 0.1046
# Epoch 22/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8899 - loss: 0.1041 - val_accuracy: 0.8807 - val_loss: 0.1046
# Epoch 23/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8870 - loss: 0.1046 - val_accuracy: 0.8975 - val_loss: 0.1046
# Epoch 24/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8909 - loss: 0.1043 - val_accuracy: 0.8811 - val_loss: 0.1046
# Epoch 25/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8889 - loss: 0.1043 - val_accuracy: 0.8943 - val_loss: 0.1046
# Epoch 26/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8889 - loss: 0.1043 - val_accuracy: 0.8849 - val_loss: 0.1046
# Epoch 27/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8920 - loss: 0.1041 - val_accuracy: 0.8967 - val_loss: 0.1046
# Epoch 28/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8930 - loss: 0.1043 - val_accuracy: 0.8689 - val_loss: 0.1046
# Epoch 29/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8896 - loss: 0.1043 - val_accuracy: 0.9013 - val_loss: 0.1046
# Epoch 30/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8925 - loss: 0.1041 - val_accuracy: 0.8790 - val_loss: 0.1046
# Epoch 31/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8917 - loss: 0.1044 - val_accuracy: 0.8992 - val_loss: 0.1046
# Epoch 32/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8919 - loss: 0.1042 - val_accuracy: 0.9070 - val_loss: 0.1046
# Epoch 33/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8946 - loss: 0.1045 - val_accuracy: 0.9002 - val_loss: 0.1046
# Epoch 34/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8927 - loss: 0.1041 - val_accuracy: 0.8962 - val_loss: 0.1046
# Epoch 35/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8989 - loss: 0.1043 - val_accuracy: 0.8755 - val_loss: 0.1046
# Epoch 36/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8934 - loss: 0.1045 - val_accuracy: 0.8987 - val_loss: 0.1046
# Epoch 37/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8978 - loss: 0.1044 - val_accuracy: 0.9164 - val_loss: 0.1046
# Epoch 38/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8977 - loss: 0.1044 - val_accuracy: 0.9154 - val_loss: 0.1046
# Epoch 39/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8956 - loss: 0.1044 - val_accuracy: 0.8617 - val_loss: 0.1046
# Epoch 40/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8953 - loss: 0.1045 - val_accuracy: 0.9217 - val_loss: 0.1046
# Epoch 41/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8992 - loss: 0.1043 - val_accuracy: 0.9173 - val_loss: 0.1046
# Epoch 42/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9006 - loss: 0.1044 - val_accuracy: 0.8958 - val_loss: 0.1046
# Epoch 43/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8999 - loss: 0.1045 - val_accuracy: 0.9179 - val_loss: 0.1046
# Epoch 44/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9029 - loss: 0.1044 - val_accuracy: 0.9211 - val_loss: 0.1046
# Epoch 45/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9045 - loss: 0.1043 - val_accuracy: 0.9366 - val_loss: 0.1046
# Epoch 46/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9031 - loss: 0.1042 - val_accuracy: 0.9171 - val_loss: 0.1046
# Epoch 47/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9031 - loss: 0.1043 - val_accuracy: 0.9106 - val_loss: 0.1046
# Epoch 48/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9053 - loss: 0.1045 - val_accuracy: 0.9427 - val_loss: 0.1046
# Epoch 49/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9040 - loss: 0.1045 - val_accuracy: 0.9123 - val_loss: 0.1046
# Epoch 50/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9086 - loss: 0.1042 - val_accuracy: 0.9091 - val_loss: 0.1046
# Epoch 51/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9089 - loss: 0.1041 - val_accuracy: 0.9274 - val_loss: 0.1046
# Epoch 52/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9048 - loss: 0.1041 - val_accuracy: 0.9130 - val_loss: 0.1046
# Epoch 53/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9065 - loss: 0.1045 - val_accuracy: 0.9421 - val_loss: 0.1046
# Epoch 54/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9117 - loss: 0.1042 - val_accuracy: 0.9382 - val_loss: 0.1046
# Epoch 55/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9103 - loss: 0.1043 - val_accuracy: 0.9546 - val_loss: 0.1046
# Epoch 56/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9129 - loss: 0.1042 - val_accuracy: 0.8936 - val_loss: 0.1046
# Epoch 57/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9103 - loss: 0.1043 - val_accuracy: 0.9179 - val_loss: 0.1046
# Epoch 58/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9130 - loss: 0.1043 - val_accuracy: 0.9458 - val_loss: 0.1046
# Epoch 59/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9166 - loss: 0.1044 - val_accuracy: 0.9331 - val_loss: 0.1046
# Epoch 60/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9166 - loss: 0.1044 - val_accuracy: 0.8881 - val_loss: 0.1046
# Epoch 61/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9135 - loss: 0.1045 - val_accuracy: 0.9200 - val_loss: 0.1046
# Epoch 62/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9156 - loss: 0.1044 - val_accuracy: 0.9206 - val_loss: 0.1046
# Epoch 63/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9180 - loss: 0.1043 - val_accuracy: 0.9107 - val_loss: 0.1046
# Epoch 64/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9193 - loss: 0.1044 - val_accuracy: 0.9030 - val_loss: 0.1046
# Epoch 65/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9170 - loss: 0.1043 - val_accuracy: 0.9097 - val_loss: 0.1046
# Epoch 66/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9146 - loss: 0.1043 - val_accuracy: 0.9321 - val_loss: 0.1046
# Epoch 67/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9179 - loss: 0.1043 - val_accuracy: 0.9116 - val_loss: 0.1046
# Epoch 68/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9189 - loss: 0.1042 - val_accuracy: 0.9052 - val_loss: 0.1046
# Epoch 69/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9151 - loss: 0.1044 - val_accuracy: 0.9174 - val_loss: 0.1046
# Epoch 70/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9154 - loss: 0.1042 - val_accuracy: 0.9406 - val_loss: 0.1046
# Epoch 71/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9183 - loss: 0.1043 - val_accuracy: 0.9193 - val_loss: 0.1046
# Epoch 72/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9185 - loss: 0.1044 - val_accuracy: 0.9259 - val_loss: 0.1046
# Epoch 73/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9181 - loss: 0.1045 - val_accuracy: 0.9216 - val_loss: 0.1046
# Epoch 74/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9216 - loss: 0.1042 - val_accuracy: 0.8940 - val_loss: 0.1046
# Epoch 75/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9179 - loss: 0.1043 - val_accuracy: 0.9011 - val_loss: 0.1046
# Epoch 76/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9180 - loss: 0.1040 - val_accuracy: 0.8943 - val_loss: 0.1046
# Epoch 77/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9180 - loss: 0.1043 - val_accuracy: 0.9490 - val_loss: 0.1046
# Epoch 78/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9211 - loss: 0.1044 - val_accuracy: 0.8957 - val_loss: 0.1046
# Epoch 79/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9198 - loss: 0.1045 - val_accuracy: 0.9253 - val_loss: 0.1046
# Epoch 80/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9199 - loss: 0.1043 - val_accuracy: 0.9595 - val_loss: 0.1046
# Epoch 81/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9209 - loss: 0.1044 - val_accuracy: 0.9276 - val_loss: 0.1046
# Epoch 82/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9189 - loss: 0.1041 - val_accuracy: 0.9124 - val_loss: 0.1046
# Epoch 83/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9217 - loss: 0.1042 - val_accuracy: 0.9079 - val_loss: 0.1046
# Epoch 84/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9181 - loss: 0.1042 - val_accuracy: 0.9383 - val_loss: 0.1046
# Epoch 85/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9242 - loss: 0.1045 - val_accuracy: 0.9319 - val_loss: 0.1046
# Epoch 86/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9204 - loss: 0.1045 - val_accuracy: 0.9175 - val_loss: 0.1046
# Epoch 87/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9182 - loss: 0.1044 - val_accuracy: 0.9359 - val_loss: 0.1046
# Epoch 88/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9227 - loss: 0.1041 - val_accuracy: 0.9224 - val_loss: 0.1046
# Epoch 89/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9209 - loss: 0.1043 - val_accuracy: 0.9179 - val_loss: 0.1046
# Epoch 90/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9208 - loss: 0.1043 - val_accuracy: 0.9171 - val_loss: 0.1046
# Epoch 91/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9204 - loss: 0.1044 - val_accuracy: 0.8923 - val_loss: 0.1046
# Epoch 92/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9201 - loss: 0.1042 - val_accuracy: 0.8988 - val_loss: 0.1046
# Epoch 93/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9230 - loss: 0.1044 - val_accuracy: 0.8946 - val_loss: 0.1046
# Epoch 94/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9201 - loss: 0.1044 - val_accuracy: 0.9317 - val_loss: 0.1046
# Epoch 95/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9192 - loss: 0.1044 - val_accuracy: 0.8926 - val_loss: 0.1046
# Epoch 96/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9203 - loss: 0.1041 - val_accuracy: 0.9324 - val_loss: 0.1046
# Epoch 97/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9237 - loss: 0.1045 - val_accuracy: 0.9150 - val_loss: 0.1046
# Epoch 98/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9199 - loss: 0.1042 - val_accuracy: 0.9211 - val_loss: 0.1046
# Epoch 99/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9236 - loss: 0.1043 - val_accuracy: 0.9385 - val_loss: 0.1046
# Epoch 100/100
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9229 - loss: 0.1045 - val_accuracy: 0.9329 - val_loss: 0.1046

# %%
filepath = './models/ae_binary.json'
weightspath = './weights/ae_binary.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  autoencoder_json = autoencoder.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(autoencoder_json)

  # serialize weights to HDF5
  autoencoder.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  autoencoder = model_from_json(loaded_model_json)

  # load weights into new model
  autoencoder.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = autoencoder.evaluate(X_test, X_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9306 - loss: 0.1044
# Test results - Loss: 0.10456154495477676 - Accuracy: 0.9329078793525696%

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_binary_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_binary_accuracy.png')
plt.show()

# %%
# representation of model layers
plot_model(autoencoder, to_file='plots/ae_binary.png', show_shapes=True,)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# calculating reconstruction error 
predictions = autoencoder.predict(X_test)
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          31494.000000  31494.000000
# mean               0.104569      0.532609
# std                0.043572      0.498943
# min                0.040626      0.000000
# 25%                0.074506      0.000000
# 50%                0.083821      1.000000
# 75%                0.151405      1.000000
# max                0.229789      1.000000

# %%
predictions.shape
# Out:
# (31494, 93)

# %% [markdown]
# ## **AE Classifier**

# %%
i_dim = predictions.shape[1]

#input layer
i_layer = Input(shape=(i_dim, ))
#hidden layer with 50 neurons
fvector = Dense(50, activation="sigmoid")(i_layer)                    
#doutput layer
o_layer = Dense(1, activation='sigmoid')(fvector)

# %%
# creating model with input, encoding, decoding, output layers
ae_classifier = Model(inputs=i_layer, outputs=o_layer)

# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
# summary of model layers
ae_classifier.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 93)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 50)                  │           4,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,751 (18.56 KB)
#  Trainable params: 4,751 (18.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# training the model on training dataset
his = ae_classifier.fit(predictions, y_test, epochs=300,batch_size=500, validation_split=0.2).history
# Out:
# Epoch 1/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5376 - loss: 0.6925 - val_accuracy: 0.7254 - val_loss: 0.6597
# Epoch 2/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7318 - loss: 0.6503 - val_accuracy: 0.8616 - val_loss: 0.6230
# Epoch 3/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8597 - loss: 0.6120 - val_accuracy: 0.8852 - val_loss: 0.5761
# Epoch 4/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8801 - loss: 0.5640 - val_accuracy: 0.8839 - val_loss: 0.5194
# Epoch 5/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.5045 - val_accuracy: 0.9000 - val_loss: 0.4586
# Epoch 6/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.4432 - val_accuracy: 0.9006 - val_loss: 0.4025
# Epoch 7/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.3891 - val_accuracy: 0.9017 - val_loss: 0.3570
# Epoch 8/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9001 - loss: 0.3489 - val_accuracy: 0.9033 - val_loss: 0.3229
# Epoch 9/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9034 - loss: 0.3159 - val_accuracy: 0.9046 - val_loss: 0.2980
# Epoch 10/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8999 - loss: 0.2962 - val_accuracy: 0.9044 - val_loss: 0.2793
# Epoch 11/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.2739 - val_accuracy: 0.9057 - val_loss: 0.2652
# Epoch 12/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9014 - loss: 0.2623 - val_accuracy: 0.9054 - val_loss: 0.2541
# Epoch 13/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9003 - loss: 0.2545 - val_accuracy: 0.9052 - val_loss: 0.2454
# Epoch 14/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - loss: 0.2424 - val_accuracy: 0.9305 - val_loss: 0.2385
# Epoch 15/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.2433 - val_accuracy: 0.9311 - val_loss: 0.2330
# Epoch 16/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.2330 - val_accuracy: 0.9089 - val_loss: 0.2291
# Epoch 17/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9121 - loss: 0.2281 - val_accuracy: 0.9105 - val_loss: 0.2253
# Epoch 18/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9150 - loss: 0.2259 - val_accuracy: 0.9073 - val_loss: 0.2225
# Epoch 19/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9109 - loss: 0.2232 - val_accuracy: 0.9105 - val_loss: 0.2201
# Epoch 20/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9129 - loss: 0.2224 - val_accuracy: 0.9079 - val_loss: 0.2184
# Epoch 21/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9153 - loss: 0.2123 - val_accuracy: 0.9073 - val_loss: 0.2166
# Epoch 22/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9092 - loss: 0.2178 - val_accuracy: 0.9100 - val_loss: 0.2150
# Epoch 23/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9149 - loss: 0.2172 - val_accuracy: 0.9095 - val_loss: 0.2138
# Epoch 24/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9135 - loss: 0.2117 - val_accuracy: 0.9114 - val_loss: 0.2127
# Epoch 25/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.2137 - val_accuracy: 0.9074 - val_loss: 0.2120
# Epoch 26/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9115 - loss: 0.2156 - val_accuracy: 0.9182 - val_loss: 0.2107
# Epoch 27/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9179 - loss: 0.2094 - val_accuracy: 0.9206 - val_loss: 0.2098
# Epoch 28/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9186 - loss: 0.2123 - val_accuracy: 0.9228 - val_loss: 0.2090
# Epoch 29/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9191 - loss: 0.2127 - val_accuracy: 0.9171 - val_loss: 0.2085
# Epoch 30/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.2130 - val_accuracy: 0.9184 - val_loss: 0.2079
# Epoch 31/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9213 - loss: 0.2102 - val_accuracy: 0.9217 - val_loss: 0.2070
# Epoch 32/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9224 - loss: 0.2073 - val_accuracy: 0.9217 - val_loss: 0.2063
# Epoch 33/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9244 - loss: 0.2089 - val_accuracy: 0.9119 - val_loss: 0.2064
# Epoch 34/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9221 - loss: 0.2060 - val_accuracy: 0.9222 - val_loss: 0.2049
# Epoch 35/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9234 - loss: 0.2055 - val_accuracy: 0.9221 - val_loss: 0.2045
# Epoch 36/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9191 - loss: 0.2123 - val_accuracy: 0.9217 - val_loss: 0.2041
# Epoch 37/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.2069 - val_accuracy: 0.9228 - val_loss: 0.2033
# Epoch 38/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9205 - loss: 0.2129 - val_accuracy: 0.9235 - val_loss: 0.2030
# Epoch 39/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9264 - loss: 0.1996 - val_accuracy: 0.9230 - val_loss: 0.2024
# Epoch 40/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.2060 - val_accuracy: 0.9240 - val_loss: 0.2020
# Epoch 41/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9270 - loss: 0.1957 - val_accuracy: 0.9240 - val_loss: 0.2017
# Epoch 42/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.2034 - val_accuracy: 0.9247 - val_loss: 0.2011
# Epoch 43/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.2040 - val_accuracy: 0.9236 - val_loss: 0.2008
# Epoch 44/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9232 - loss: 0.2032 - val_accuracy: 0.9241 - val_loss: 0.2008
# Epoch 45/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9248 - loss: 0.2024 - val_accuracy: 0.9221 - val_loss: 0.2001
# Epoch 46/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9187 - loss: 0.2084 - val_accuracy: 0.9217 - val_loss: 0.1997
# Epoch 47/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9221 - loss: 0.2021 - val_accuracy: 0.9219 - val_loss: 0.1993
# Epoch 48/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9213 - loss: 0.2044 - val_accuracy: 0.9221 - val_loss: 0.1990
# Epoch 49/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9231 - loss: 0.2008 - val_accuracy: 0.9219 - val_loss: 0.1990
# Epoch 50/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9239 - loss: 0.1978 - val_accuracy: 0.9219 - val_loss: 0.1986
# Epoch 51/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9204 - loss: 0.2026 - val_accuracy: 0.9214 - val_loss: 0.1982
# Epoch 52/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9193 - loss: 0.2047 - val_accuracy: 0.9216 - val_loss: 0.1980
# Epoch 53/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9227 - loss: 0.2010 - val_accuracy: 0.9217 - val_loss: 0.1977
# Epoch 54/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.2028 - val_accuracy: 0.9221 - val_loss: 0.1973
# Epoch 55/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.2043 - val_accuracy: 0.9222 - val_loss: 0.1971
# Epoch 56/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9194 - loss: 0.2059 - val_accuracy: 0.9225 - val_loss: 0.1968
# Epoch 57/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9202 - loss: 0.2051 - val_accuracy: 0.9222 - val_loss: 0.1967
# Epoch 58/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9218 - loss: 0.2051 - val_accuracy: 0.9221 - val_loss: 0.1966
# Epoch 59/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9212 - loss: 0.2051 - val_accuracy: 0.9228 - val_loss: 0.1961
# Epoch 60/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9223 - loss: 0.1997 - val_accuracy: 0.9222 - val_loss: 0.1961
# Epoch 61/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.1965 - val_accuracy: 0.9240 - val_loss: 0.1956
# Epoch 62/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9239 - loss: 0.1967 - val_accuracy: 0.9241 - val_loss: 0.1955
# Epoch 63/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9207 - loss: 0.2046 - val_accuracy: 0.9287 - val_loss: 0.1952
# Epoch 64/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9241 - loss: 0.1998 - val_accuracy: 0.9297 - val_loss: 0.1950
# Epoch 65/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9289 - loss: 0.1906 - val_accuracy: 0.9235 - val_loss: 0.1951
# Epoch 66/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9238 - loss: 0.2039 - val_accuracy: 0.9289 - val_loss: 0.1946
# Epoch 67/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9257 - loss: 0.1983 - val_accuracy: 0.9254 - val_loss: 0.1947
# Epoch 68/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9232 - loss: 0.2001 - val_accuracy: 0.9289 - val_loss: 0.1943
# Epoch 69/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9227 - loss: 0.2017 - val_accuracy: 0.9289 - val_loss: 0.1941
# Epoch 70/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1946 - val_accuracy: 0.9219 - val_loss: 0.1953
# Epoch 71/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9239 - loss: 0.1978 - val_accuracy: 0.9295 - val_loss: 0.1937
# Epoch 72/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9280 - loss: 0.1947 - val_accuracy: 0.9295 - val_loss: 0.1936
# Epoch 73/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9263 - loss: 0.2005 - val_accuracy: 0.9287 - val_loss: 0.1938
# Epoch 74/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9270 - loss: 0.1949 - val_accuracy: 0.9295 - val_loss: 0.1933
# Epoch 75/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9249 - loss: 0.2023 - val_accuracy: 0.9300 - val_loss: 0.1930
# Epoch 76/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1940 - val_accuracy: 0.9297 - val_loss: 0.1932
# Epoch 77/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9271 - loss: 0.1952 - val_accuracy: 0.9295 - val_loss: 0.1930
# Epoch 78/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1912 - val_accuracy: 0.9289 - val_loss: 0.1934
# Epoch 79/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9253 - loss: 0.2020 - val_accuracy: 0.9300 - val_loss: 0.1925
# Epoch 80/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.1930 - val_accuracy: 0.9303 - val_loss: 0.1923
# Epoch 81/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.1953 - val_accuracy: 0.9301 - val_loss: 0.1923
# Epoch 82/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9278 - loss: 0.1969 - val_accuracy: 0.9295 - val_loss: 0.1926
# Epoch 83/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9259 - loss: 0.2000 - val_accuracy: 0.9305 - val_loss: 0.1920
# Epoch 84/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9258 - loss: 0.1974 - val_accuracy: 0.9301 - val_loss: 0.1922
# Epoch 85/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9263 - loss: 0.1991 - val_accuracy: 0.9298 - val_loss: 0.1922
# Epoch 86/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.1962 - val_accuracy: 0.9298 - val_loss: 0.1923
# Epoch 87/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9249 - loss: 0.1980 - val_accuracy: 0.9303 - val_loss: 0.1917
# Epoch 88/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9277 - loss: 0.1972 - val_accuracy: 0.9305 - val_loss: 0.1916
# Epoch 89/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9284 - loss: 0.1946 - val_accuracy: 0.9301 - val_loss: 0.1917
# Epoch 90/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.1978 - val_accuracy: 0.9303 - val_loss: 0.1915
# Epoch 91/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9278 - loss: 0.1985 - val_accuracy: 0.9301 - val_loss: 0.1916
# Epoch 92/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9272 - loss: 0.1975 - val_accuracy: 0.9300 - val_loss: 0.1918
# Epoch 93/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9252 - loss: 0.2000 - val_accuracy: 0.9306 - val_loss: 0.1913
# Epoch 94/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.1937 - val_accuracy: 0.9301 - val_loss: 0.1922
# Epoch 95/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9276 - loss: 0.1950 - val_accuracy: 0.9305 - val_loss: 0.1914
# Epoch 96/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9255 - loss: 0.1970 - val_accuracy: 0.9309 - val_loss: 0.1911
# Epoch 97/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.1921 - val_accuracy: 0.9306 - val_loss: 0.1914
# Epoch 98/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9276 - loss: 0.1957 - val_accuracy: 0.9314 - val_loss: 0.1908
# Epoch 99/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9262 - loss: 0.1990 - val_accuracy: 0.9314 - val_loss: 0.1908
# Epoch 100/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.1930 - val_accuracy: 0.9314 - val_loss: 0.1908
# Epoch 101/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9267 - loss: 0.1994 - val_accuracy: 0.9314 - val_loss: 0.1907
# Epoch 102/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9286 - loss: 0.1994 - val_accuracy: 0.9314 - val_loss: 0.1907
# Epoch 103/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.1917 - val_accuracy: 0.9316 - val_loss: 0.1907
# Epoch 104/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1929 - val_accuracy: 0.9309 - val_loss: 0.1908
# Epoch 105/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.1943 - val_accuracy: 0.9314 - val_loss: 0.1907
# Epoch 106/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1965 - val_accuracy: 0.9313 - val_loss: 0.1908
# Epoch 107/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.1932 - val_accuracy: 0.9316 - val_loss: 0.1907
# Epoch 108/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9282 - loss: 0.1966 - val_accuracy: 0.9313 - val_loss: 0.1916
# Epoch 109/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9260 - loss: 0.2012 - val_accuracy: 0.9316 - val_loss: 0.1910
# Epoch 110/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1935 - val_accuracy: 0.9316 - val_loss: 0.1908
# Epoch 111/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.1924 - val_accuracy: 0.9314 - val_loss: 0.1912
# Epoch 112/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.1982 - val_accuracy: 0.9316 - val_loss: 0.1905
# Epoch 113/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.1988 - val_accuracy: 0.9316 - val_loss: 0.1908
# Epoch 114/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.1950 - val_accuracy: 0.9319 - val_loss: 0.1904
# Epoch 115/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.1967 - val_accuracy: 0.9319 - val_loss: 0.1904
# Epoch 116/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9262 - loss: 0.2017 - val_accuracy: 0.9321 - val_loss: 0.1903
# Epoch 117/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1997 - val_accuracy: 0.9316 - val_loss: 0.1905
# Epoch 118/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9264 - loss: 0.2007 - val_accuracy: 0.9322 - val_loss: 0.1904
# Epoch 119/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.1965 - val_accuracy: 0.9317 - val_loss: 0.1904
# Epoch 120/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.1960 - val_accuracy: 0.9314 - val_loss: 0.1904
# Epoch 121/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.1961 - val_accuracy: 0.9316 - val_loss: 0.1907
# Epoch 122/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9324 - loss: 0.1894 - val_accuracy: 0.9316 - val_loss: 0.1906
# Epoch 123/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9284 - loss: 0.1978 - val_accuracy: 0.9314 - val_loss: 0.1905
# Epoch 124/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9318 - loss: 0.1903 - val_accuracy: 0.9314 - val_loss: 0.1905
# Epoch 125/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.1930 - val_accuracy: 0.9316 - val_loss: 0.1907
# Epoch 126/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1941 - val_accuracy: 0.9319 - val_loss: 0.1903
# Epoch 127/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9310 - loss: 0.1932 - val_accuracy: 0.9321 - val_loss: 0.1902
# Epoch 128/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.1978 - val_accuracy: 0.9321 - val_loss: 0.1902
# Epoch 129/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9277 - loss: 0.1994 - val_accuracy: 0.9322 - val_loss: 0.1901
# Epoch 130/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.1922 - val_accuracy: 0.9317 - val_loss: 0.1905
# Epoch 131/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1941 - val_accuracy: 0.9316 - val_loss: 0.1904
# Epoch 132/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1980 - val_accuracy: 0.9328 - val_loss: 0.1902
# Epoch 133/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.1930 - val_accuracy: 0.9324 - val_loss: 0.1901
# Epoch 134/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1946 - val_accuracy: 0.9327 - val_loss: 0.1900
# Epoch 135/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.1938 - val_accuracy: 0.9317 - val_loss: 0.1905
# Epoch 136/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1952 - val_accuracy: 0.9325 - val_loss: 0.1900
# Epoch 137/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.1940 - val_accuracy: 0.9332 - val_loss: 0.1901
# Epoch 138/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9306 - loss: 0.1941 - val_accuracy: 0.9324 - val_loss: 0.1901
# Epoch 139/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1965 - val_accuracy: 0.9324 - val_loss: 0.1901
# Epoch 140/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9286 - loss: 0.1956 - val_accuracy: 0.9324 - val_loss: 0.1900
# Epoch 141/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.2003 - val_accuracy: 0.9325 - val_loss: 0.1900
# Epoch 142/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1952 - val_accuracy: 0.9328 - val_loss: 0.1899
# Epoch 143/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.1958 - val_accuracy: 0.9328 - val_loss: 0.1899
# Epoch 144/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9287 - loss: 0.1972 - val_accuracy: 0.9325 - val_loss: 0.1901
# Epoch 145/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.1892 - val_accuracy: 0.9325 - val_loss: 0.1899
# Epoch 146/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1951 - val_accuracy: 0.9327 - val_loss: 0.1899
# Epoch 147/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.1985 - val_accuracy: 0.9321 - val_loss: 0.1902
# Epoch 148/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.1923 - val_accuracy: 0.9317 - val_loss: 0.1902
# Epoch 149/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9289 - loss: 0.1978 - val_accuracy: 0.9327 - val_loss: 0.1899
# Epoch 150/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9331 - loss: 0.1905 - val_accuracy: 0.9330 - val_loss: 0.1898
# Epoch 151/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1937 - val_accuracy: 0.9333 - val_loss: 0.1900
# Epoch 152/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.1929 - val_accuracy: 0.9333 - val_loss: 0.1899
# Epoch 153/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9277 - loss: 0.1997 - val_accuracy: 0.9330 - val_loss: 0.1898
# Epoch 154/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.1940 - val_accuracy: 0.9327 - val_loss: 0.1898
# Epoch 155/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.2007 - val_accuracy: 0.9325 - val_loss: 0.1899
# Epoch 156/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9289 - loss: 0.1931 - val_accuracy: 0.9327 - val_loss: 0.1899
# Epoch 157/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9267 - loss: 0.1978 - val_accuracy: 0.9330 - val_loss: 0.1899
# Epoch 158/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9278 - loss: 0.2004 - val_accuracy: 0.9330 - val_loss: 0.1898
# Epoch 159/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9306 - loss: 0.1939 - val_accuracy: 0.9325 - val_loss: 0.1898
# Epoch 160/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.1952 - val_accuracy: 0.9328 - val_loss: 0.1898
# Epoch 161/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.2012 - val_accuracy: 0.9325 - val_loss: 0.1899
# Epoch 162/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.1982 - val_accuracy: 0.9330 - val_loss: 0.1897
# Epoch 163/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1918 - val_accuracy: 0.9319 - val_loss: 0.1903
# Epoch 164/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.2022 - val_accuracy: 0.9328 - val_loss: 0.1898
# Epoch 165/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1983 - val_accuracy: 0.9328 - val_loss: 0.1898
# Epoch 166/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.1936 - val_accuracy: 0.9328 - val_loss: 0.1898
# Epoch 167/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.1963 - val_accuracy: 0.9322 - val_loss: 0.1900
# Epoch 168/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1986 - val_accuracy: 0.9328 - val_loss: 0.1897
# Epoch 169/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.1919 - val_accuracy: 0.9325 - val_loss: 0.1898
# Epoch 170/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.1975 - val_accuracy: 0.9319 - val_loss: 0.1907
# Epoch 171/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1945 - val_accuracy: 0.9327 - val_loss: 0.1897
# Epoch 172/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9305 - loss: 0.1931 - val_accuracy: 0.9316 - val_loss: 0.1908
# Epoch 173/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9271 - loss: 0.1969 - val_accuracy: 0.9330 - val_loss: 0.1897
# Epoch 174/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.1970 - val_accuracy: 0.9327 - val_loss: 0.1896
# Epoch 175/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9301 - loss: 0.1937 - val_accuracy: 0.9333 - val_loss: 0.1896
# Epoch 176/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9280 - loss: 0.2020 - val_accuracy: 0.9325 - val_loss: 0.1899
# Epoch 177/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1884 - val_accuracy: 0.9328 - val_loss: 0.1897
# Epoch 178/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9310 - loss: 0.1943 - val_accuracy: 0.9327 - val_loss: 0.1896
# Epoch 179/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.1932 - val_accuracy: 0.9325 - val_loss: 0.1896
# Epoch 180/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9302 - loss: 0.1951 - val_accuracy: 0.9325 - val_loss: 0.1898
# Epoch 181/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1937 - val_accuracy: 0.9321 - val_loss: 0.1900
# Epoch 182/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9310 - loss: 0.1936 - val_accuracy: 0.9328 - val_loss: 0.1897
# Epoch 183/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.1984 - val_accuracy: 0.9324 - val_loss: 0.1898
# Epoch 184/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1967 - val_accuracy: 0.9330 - val_loss: 0.1895
# Epoch 185/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 0.1919 - val_accuracy: 0.9325 - val_loss: 0.1896
# Epoch 186/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9270 - loss: 0.2008 - val_accuracy: 0.9328 - val_loss: 0.1894
# Epoch 187/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.1988 - val_accuracy: 0.9333 - val_loss: 0.1895
# Epoch 188/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.1978 - val_accuracy: 0.9322 - val_loss: 0.1898
# Epoch 189/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 0.1909 - val_accuracy: 0.9324 - val_loss: 0.1896
# Epoch 190/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.1870 - val_accuracy: 0.9322 - val_loss: 0.1897
# Epoch 191/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9302 - loss: 0.1936 - val_accuracy: 0.9325 - val_loss: 0.1895
# Epoch 192/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9284 - loss: 0.1981 - val_accuracy: 0.9327 - val_loss: 0.1894
# Epoch 193/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.1895 - val_accuracy: 0.9327 - val_loss: 0.1893
# Epoch 194/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9280 - loss: 0.1978 - val_accuracy: 0.9324 - val_loss: 0.1895
# Epoch 195/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.1932 - val_accuracy: 0.9325 - val_loss: 0.1893
# Epoch 196/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1938 - val_accuracy: 0.9328 - val_loss: 0.1892
# Epoch 197/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1955 - val_accuracy: 0.9325 - val_loss: 0.1894
# Epoch 198/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9289 - loss: 0.1961 - val_accuracy: 0.9327 - val_loss: 0.1892
# Epoch 199/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9310 - loss: 0.1902 - val_accuracy: 0.9321 - val_loss: 0.1896
# Epoch 200/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.1952 - val_accuracy: 0.9327 - val_loss: 0.1892
# Epoch 201/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1946 - val_accuracy: 0.9330 - val_loss: 0.1891
# Epoch 202/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1974 - val_accuracy: 0.9327 - val_loss: 0.1894
# Epoch 203/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9332 - loss: 0.1903 - val_accuracy: 0.9321 - val_loss: 0.1895
# Epoch 204/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9276 - loss: 0.2005 - val_accuracy: 0.9322 - val_loss: 0.1894
# Epoch 205/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1955 - val_accuracy: 0.9327 - val_loss: 0.1892
# Epoch 206/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9282 - loss: 0.1986 - val_accuracy: 0.9328 - val_loss: 0.1890
# Epoch 207/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9290 - loss: 0.1950 - val_accuracy: 0.9321 - val_loss: 0.1894
# Epoch 208/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1924 - val_accuracy: 0.9332 - val_loss: 0.1888
# Epoch 209/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.1922 - val_accuracy: 0.9330 - val_loss: 0.1888
# Epoch 210/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.2003 - val_accuracy: 0.9327 - val_loss: 0.1889
# Epoch 211/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1906 - val_accuracy: 0.9333 - val_loss: 0.1887
# Epoch 212/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1916 - val_accuracy: 0.9332 - val_loss: 0.1887
# Epoch 213/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9301 - loss: 0.1945 - val_accuracy: 0.9324 - val_loss: 0.1891
# Epoch 214/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1922 - val_accuracy: 0.9327 - val_loss: 0.1888
# Epoch 215/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9327 - loss: 0.1879 - val_accuracy: 0.9332 - val_loss: 0.1887
# Epoch 216/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.1900 - val_accuracy: 0.9327 - val_loss: 0.1888
# Epoch 217/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9274 - loss: 0.1944 - val_accuracy: 0.9324 - val_loss: 0.1890
# Epoch 218/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9287 - loss: 0.1959 - val_accuracy: 0.9322 - val_loss: 0.1893
# Epoch 219/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1930 - val_accuracy: 0.9327 - val_loss: 0.1886
# Epoch 220/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9284 - loss: 0.1950 - val_accuracy: 0.9327 - val_loss: 0.1885
# Epoch 221/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.1916 - val_accuracy: 0.9322 - val_loss: 0.1888
# Epoch 222/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.1933 - val_accuracy: 0.9332 - val_loss: 0.1883
# Epoch 223/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1951 - val_accuracy: 0.9327 - val_loss: 0.1885
# Epoch 224/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1972 - val_accuracy: 0.9335 - val_loss: 0.1881
# Epoch 225/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.1885 - val_accuracy: 0.9325 - val_loss: 0.1882
# Epoch 226/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9306 - loss: 0.1896 - val_accuracy: 0.9332 - val_loss: 0.1880
# Epoch 227/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1891 - val_accuracy: 0.9332 - val_loss: 0.1880
# Epoch 228/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9308 - loss: 0.1932 - val_accuracy: 0.9327 - val_loss: 0.1880
# Epoch 229/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9323 - loss: 0.1924 - val_accuracy: 0.9327 - val_loss: 0.1879
# Epoch 230/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9304 - loss: 0.1928 - val_accuracy: 0.9330 - val_loss: 0.1876
# Epoch 231/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.1914 - val_accuracy: 0.9327 - val_loss: 0.1878
# Epoch 232/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.1918 - val_accuracy: 0.9332 - val_loss: 0.1876
# Epoch 233/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1915 - val_accuracy: 0.9332 - val_loss: 0.1875
# Epoch 234/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1917 - val_accuracy: 0.9327 - val_loss: 0.1874
# Epoch 235/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.1922 - val_accuracy: 0.9328 - val_loss: 0.1874
# Epoch 236/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.1883 - val_accuracy: 0.9332 - val_loss: 0.1873
# Epoch 237/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9301 - loss: 0.1913 - val_accuracy: 0.9328 - val_loss: 0.1875
# Epoch 238/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.1932 - val_accuracy: 0.9327 - val_loss: 0.1873
# Epoch 239/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9312 - loss: 0.1907 - val_accuracy: 0.9328 - val_loss: 0.1873
# Epoch 240/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1933 - val_accuracy: 0.9335 - val_loss: 0.1869
# Epoch 241/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1916 - val_accuracy: 0.9333 - val_loss: 0.1867
# Epoch 242/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1933 - val_accuracy: 0.9330 - val_loss: 0.1868
# Epoch 243/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9304 - loss: 0.1934 - val_accuracy: 0.9330 - val_loss: 0.1867
# Epoch 244/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9338 - loss: 0.1861 - val_accuracy: 0.9328 - val_loss: 0.1866
# Epoch 245/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1886 - val_accuracy: 0.9338 - val_loss: 0.1864
# Epoch 246/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.1907 - val_accuracy: 0.9335 - val_loss: 0.1864
# Epoch 247/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9304 - loss: 0.1898 - val_accuracy: 0.9335 - val_loss: 0.1861
# Epoch 248/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.1942 - val_accuracy: 0.9338 - val_loss: 0.1860
# Epoch 249/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.1905 - val_accuracy: 0.9340 - val_loss: 0.1859
# Epoch 250/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9300 - loss: 0.1964 - val_accuracy: 0.9327 - val_loss: 0.1863
# Epoch 251/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1882 - val_accuracy: 0.9325 - val_loss: 0.1863
# Epoch 252/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9313 - loss: 0.1893 - val_accuracy: 0.9336 - val_loss: 0.1855
# Epoch 253/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9275 - loss: 0.1974 - val_accuracy: 0.9330 - val_loss: 0.1858
# Epoch 254/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9308 - loss: 0.1920 - val_accuracy: 0.9325 - val_loss: 0.1860
# Epoch 255/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9292 - loss: 0.1898 - val_accuracy: 0.9336 - val_loss: 0.1852
# Epoch 256/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.1899 - val_accuracy: 0.9341 - val_loss: 0.1850
# Epoch 257/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.1887 - val_accuracy: 0.9341 - val_loss: 0.1849
# Epoch 258/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9299 - loss: 0.1902 - val_accuracy: 0.9336 - val_loss: 0.1847
# Epoch 259/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9335 - loss: 0.1862 - val_accuracy: 0.9341 - val_loss: 0.1846
# Epoch 260/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9301 - loss: 0.1893 - val_accuracy: 0.9336 - val_loss: 0.1844
# Epoch 261/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9303 - loss: 0.1880 - val_accuracy: 0.9338 - val_loss: 0.1844
# Epoch 262/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9313 - loss: 0.1908 - val_accuracy: 0.9338 - val_loss: 0.1841
# Epoch 263/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9305 - loss: 0.1934 - val_accuracy: 0.9333 - val_loss: 0.1842
# Epoch 264/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9312 - loss: 0.1897 - val_accuracy: 0.9338 - val_loss: 0.1838
# Epoch 265/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9291 - loss: 0.1930 - val_accuracy: 0.9338 - val_loss: 0.1838
# Epoch 266/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9318 - loss: 0.1909 - val_accuracy: 0.9336 - val_loss: 0.1836
# Epoch 267/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9324 - loss: 0.1857 - val_accuracy: 0.9333 - val_loss: 0.1837
# Epoch 268/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.1863 - val_accuracy: 0.9330 - val_loss: 0.1839
# Epoch 269/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9320 - loss: 0.1848 - val_accuracy: 0.9340 - val_loss: 0.1831
# Epoch 270/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9325 - loss: 0.1830 - val_accuracy: 0.9333 - val_loss: 0.1830
# Epoch 271/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1877 - val_accuracy: 0.9338 - val_loss: 0.1828
# Epoch 272/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 0.1880 - val_accuracy: 0.9341 - val_loss: 0.1825
# Epoch 273/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9328 - loss: 0.1871 - val_accuracy: 0.9338 - val_loss: 0.1824
# Epoch 274/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.1874 - val_accuracy: 0.9338 - val_loss: 0.1822
# Epoch 275/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.1905 - val_accuracy: 0.9333 - val_loss: 0.1823
# Epoch 276/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9313 - loss: 0.1909 - val_accuracy: 0.9336 - val_loss: 0.1820
# Epoch 277/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1881 - val_accuracy: 0.9348 - val_loss: 0.1816
# Epoch 278/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9323 - loss: 0.1879 - val_accuracy: 0.9351 - val_loss: 0.1814
# Epoch 279/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.1911 - val_accuracy: 0.9338 - val_loss: 0.1814
# Epoch 280/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.1902 - val_accuracy: 0.9344 - val_loss: 0.1811
# Epoch 281/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9302 - loss: 0.1885 - val_accuracy: 0.9338 - val_loss: 0.1811
# Epoch 282/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9338 - loss: 0.1832 - val_accuracy: 0.9333 - val_loss: 0.1811
# Epoch 283/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1900 - val_accuracy: 0.9344 - val_loss: 0.1807
# Epoch 284/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9318 - loss: 0.1885 - val_accuracy: 0.9354 - val_loss: 0.1803
# Epoch 285/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9339 - loss: 0.1832 - val_accuracy: 0.9354 - val_loss: 0.1801
# Epoch 286/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9324 - loss: 0.1863 - val_accuracy: 0.9351 - val_loss: 0.1800
# Epoch 287/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9327 - loss: 0.1833 - val_accuracy: 0.9338 - val_loss: 0.1804
# Epoch 288/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9282 - loss: 0.1893 - val_accuracy: 0.9348 - val_loss: 0.1798
# Epoch 289/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9319 - loss: 0.1849 - val_accuracy: 0.9351 - val_loss: 0.1796
# Epoch 290/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9330 - loss: 0.1842 - val_accuracy: 0.9355 - val_loss: 0.1789
# Epoch 291/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9332 - loss: 0.1850 - val_accuracy: 0.9354 - val_loss: 0.1790
# Epoch 292/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9331 - loss: 0.1839 - val_accuracy: 0.9354 - val_loss: 0.1785
# Epoch 293/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1866 - val_accuracy: 0.9349 - val_loss: 0.1787
# Epoch 294/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9327 - loss: 0.1802 - val_accuracy: 0.9357 - val_loss: 0.1781
# Epoch 295/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9335 - loss: 0.1827 - val_accuracy: 0.9352 - val_loss: 0.1781
# Epoch 296/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.1798 - val_accuracy: 0.9354 - val_loss: 0.1778
# Epoch 297/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1890 - val_accuracy: 0.9355 - val_loss: 0.1776
# Epoch 298/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.1881 - val_accuracy: 0.9357 - val_loss: 0.1774
# Epoch 299/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9347 - loss: 0.1765 - val_accuracy: 0.9359 - val_loss: 0.1771
# Epoch 300/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9333 - loss: 0.1847 - val_accuracy: 0.9362 - val_loss: 0.1769

# %%
filepath = './models/ae_classifier_binary.json'
weightspath = './weights/ae_classifier_binary.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  ae_classifier_json = ae_classifier.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(ae_classifier_json)

  # serialize weights to HDF5
  ae_classifier.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  ae_classifier = model_from_json(loaded_model_json)

  # load weights into new model
  ae_classifier.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[195], line 10
#       7   json_file.write(ae_classifier_json)
#       9 # serialize weights to HDF5
# ---> 10 ae_classifier.save_weights(weightspath)
#      11 print("Saved model to disk")
#      13 # load json and create model
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\model.py:319, in Model.save_weights(self, filepath, overwrite)
#     309 """Saves all layer weights to a `.weights.h5` file.
#     310
#     311 Args:
#    (...)
#     316         via an interactive prompt.
#     317 """
#     318 if not str(filepath).endswith(".weights.h5"):
# --> 319     raise ValueError(
#     320         "The filename must end in `.weights.h5`. "
#     321         f"Received: filepath={filepath}"
#     322     )
#     323 try:
#     324     exists = os.path.exists(filepath)
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=./weights/ae_classifier_binary.h5

# %%
ae_classifier.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = ae_classifier.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# %%
# representation of model layers
plot_model(ae_classifier, to_file='plots/ae_classifier_binary.png', show_shapes=True)

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(his['loss'])
plt.plot(his['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_classifier_binary_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(his['accuracy'])
plt.plot(his['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_classifier_binary_accuracy.png')
plt.show()

# %%
y_pred = ae_classifier.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
#auc = auc(fpr, tpr)

# %%
plt.plot([0, 1], [0, 1], 'k--')
#plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.plot(fpr, tpr)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/ae_binary_roc.png')
plt.show()

# %%
pred = ae_classifier.predict(X_test)
y_classes = (ae_classifier.predict(X_test)>0.5).astype('int32')

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded, original)
Y = multi_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
lsvm=SVC(kernel='linear',gamma='auto')
lsvm.fit(X_train,y_train) # training model on training dataset

# %%
# saving trained model to disk
pkl_filename = "./models/lsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loade model from disk")

# %%
y_pred=lsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("LSVM-Classifier Multi-class Set-Accuracy is ", ac)

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Linear SVM Multi-class Classification")
plt.savefig('plots/lsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Multi-class Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto')
qsvm.fit(X_train,y_train) # training model on training dataset

# %%
pkl_filename = "./models/qsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred=qsvm.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QSVM-Classifier Multi-class Set-Accuracy is ", ac)

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=1.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=1.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Quadratic SVM Multi-class Classification")
plt.savefig('plots/qsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Multi-class Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train) # training model on training dataset

# %%
pkl_filename = "./models/knn_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred=knn.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("KNN-Classifier Multi-class Set-Accuracy is ", ac)

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("KNN Multi Classification")
plt.savefig('plots/knn_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Linear Discriminant Analysis Classifier (Multi-class Classification)**

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train) # training model on training dataset

# %%
pkl_filename = "./models/lda_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lda = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred = lda.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("LDA-Classifier Set-Accuracy is ", ac)

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Linear Discriminant Analysis Multi-class Classification")
plt.savefig('plots/lda_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Quadratic Discriminant Analysis Classifier (Multi-class Classification)**

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train) # training model on training dataset

# %%
pkl_filename = "./models/qda_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qda = pickle.load(file)
  print("Loaded model from disk")

# %%
y_pred = qda.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QDA-Classifier Multi-class Set-Accuracy is ", ac)

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Quadratic Discriminant Analysis Multi-class Classification")
plt.savefig('plots/qda_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93]  # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # initializing model
# input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with softmax activation
mlp.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()

# %%
# training the model on training dataset
history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)

# %%
filepath = './models/mlp_multi.json'
weightspath = './weights/mlp_multi.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")
  
  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_multi_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/mlp_multi_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(mlp, to_file='plots/mlp_multi.png', show_shapes=True,)

# %%
n_classes = len(le2.classes_)
n_classes

# %%
y_pred = mlp.predict(X_test)

# %%
fpr_mlp = dict()
tpr_mlp = dict()
roc_auc_mlp = dict()
for i in range(n_classes):
    fpr_mlp[i], tpr_mlp[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
    roc_auc_mlp[i] = auc(fpr_mlp[i], tpr_mlp[i])

# %%
for i in range(n_classes):
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_mlp[i], tpr_mlp[i], label='Keras (area = {:.3f})'.format(roc_auc_mlp[i]))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.savefig('plots/mlp_multi_roc'+str(i)+'.png')
  plt.show()

# %%
pred = mlp.predict(X_test)

# %%
for j in range(0,pred.shape[1]):
  for i in range(0,pred.shape[0]):
    pred[i][j] = int(round(pred[i][j]))

# %%
pred_df = pd.DataFrame(pred,columns=y_test.columns)

# %%
print("Recall Score - ",recall_score(y_test,pred_df.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,pred_df.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,pred_df.astype('uint8'),average='micro'))

# %% [markdown]
# # **Auto Encoder Classifier (Multi-class Classification)**

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test = train_test_split(multi_data, test_size=0.25, random_state=42)

# %%
# dataset excluding target attribute (encoded, one-hot-encoded,original)
y_train = X_train[['Dos','normal','Probe','R2L','U2R']]

X_train = X_train.drop(['intrusion','Dos','normal','Probe','R2L','U2R','label'],axis=1)

#y_test = X_test['intrusion'] # target attribute
y_test = X_test[['Dos','normal','Probe','R2L','U2R']]

# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_test = X_test.drop(['intrusion','Dos','normal','Probe','R2L','U2R','label'],axis=1)

# %%
X = multi_data.iloc[:,0:93]  # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes

# %%
X_train = X_train.values
X_test = X_test.values
y_test = y_test.values

# %%
input_dim = X_train.shape[1]
encoding_dim = 50

#input layer
input_layer = Input(shape=(input_dim, ))
#encoding layer with 50 neurons
encoder = Dense(encoding_dim, activation="relu")(input_layer)           
#decoding and output layer
output_layer = Dense(input_dim, activation='softmax')(encoder)

# %%
# creating model with input, encoding, decoding, output layers
autoencoder = Model(inputs=input_layer, outputs=output_layer)

# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# summary of model layers
autoencoder.summary()

# %%
# training the model on training dataset
history = autoencoder.fit(X_train, X_train, epochs=100,batch_size=500,validation_data=(X_test, X_test)).history

# %%
filepath = './models/ae_multi.json'
weightspath = './weights/ae_multi.h5'
if (not path.isfile(filepath)):  
  # serialize model to JSON
  autoencoder_json = autoencoder.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(autoencoder_json)

  # serialize weights to HDF5
  autoencoder.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  autoencoder = model_from_json(loaded_model_json)

  # load weights into new model
  autoencoder.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = autoencoder.evaluate(X_test, X_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_multi_loss.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_multi_accuracy.png')
plt.show()

# %%
# representation of model layers
plot_model(autoencoder, to_file='plots/ae_multi.png', show_shapes=True,)

# %%
# calculating reconstruction error
predictions = autoencoder.predict(X_test)

# %% [markdown]
# ## **AE Classifier**

# %%
i_dim = predictions.shape[1]

#input layer
i_layer = Input(shape=(i_dim, ))
#hidden layer with 48 neurons
fvector = Dense(48, activation="sigmoid")(i_layer)   
#fvector = Dense(24, activation='tanh')(fvector)                 
#doutput layer
o_layer = Dense(5, activation='sigmoid')(fvector)

# %%
# creating model with input, encoding, decoding, output layers
ae_classifier = Model(inputs=i_layer, outputs=o_layer)

# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
ae_classifier.summary()

# %%
# training the model on training dataset
his = ae_classifier.fit(predictions, y_test, epochs=200,batch_size=700, validation_split=0.2).history

# %%
filepath = './models/ae_classifier_multi.json'
weightspath = './weights/ae_classifier_multi.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  ae_classifier_json = ae_classifier.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(ae_classifier_json)

  # serialize weights to HDF5
  ae_classifier.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  ae_classifier = model_from_json(loaded_model_json)

  # load weights into new model
  ae_classifier.load_weights(weightspath)
  print("Loaded model from disk")

# %%
# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = ae_classifier.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# %%
# representation of model layers
plot_model(ae_classifier, to_file='plots/ae_classifier_multi.png', show_shapes=True)

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(his['loss'])
plt.plot(his['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_classifier_multi_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(his['accuracy'])
plt.plot(his['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_classifier_multi_accuracy.png')
plt.show()

# %%
y_pred = ae_classifier.predict(X_test)

# %%
fpr_ae = dict()
tpr_ae = dict()
roc_auc_ae = dict()
for i in range(n_classes):
    fpr_ae[i], tpr_ae[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc_ae[i] = auc(fpr_ae[i], tpr_ae[i])

# %%
for i in range(n_classes):
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_ae[i], tpr_ae[i], label='Keras (area = {:.3f})'.format(roc_auc_ae[i]))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.savefig('plots/ae_classifier_multi_roc'+str(i)+'.png')
  plt.show()

# %%
for j in range(0,y_pred.shape[1]):
  for i in range(0,y_pred.shape[0]):
    y_pred[i][j] = int(round(y_pred[i][j]))

# %%
print("Recall Score - ",recall_score(y_test,y_pred.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,y_pred.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,y_pred.astype('uint8'),average='micro'))
